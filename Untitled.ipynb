# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit


#import seaborn as sns
import pandas as pd

from scipy.optimize import minimize_scalar;


#from lmfit.models import LinearModel, LorentzianModel

# %%
# Define the Lorentzian function
def lorentzian(x, x0, gamma, A):
    return A * (gamma**2 / ((x - x0)**2 + gamma**2))

# %%
df = (pd.read_excel("deneme.xlsx"))
column = len(df.iloc[0,:])
row = len(df.iloc[:,0])
df
# Out:
#               NM        Ar      Ar.1      Ar.2
# 0     380.141529  0.076063  0.075953  0.077101
# 1     380.433167  0.077892  0.077120  0.078238
# 2     380.724787  0.080088  0.078817  0.078296
# 3     381.016389  0.079170  0.079103  0.077630
# 4     381.307971  0.078242  0.078596  0.077329
# ...          ...       ...       ...       ...
# 1448  779.038373  0.017882  0.017921  0.018067
# 1449  779.295017  0.018070  0.017932  0.017709
# 1450  779.551631  0.017775  0.017385  0.017581
# 1451  779.808216  0.017716  0.017346  0.017441
# 1452  780.064771  0.017356  0.017662  0.017235
#
# [1453 rows x 4 columns]

# %%
h=475
#df=df[df.NM<(h+50)]
#df=df[df.NM>(h-50)]

#initial_guess = [0.1, 0.1, 2.0]
A = 0.09463919098664426
x0 = 274.3146806018545
gamma = 585.8269681890237 

initial_guess = [ A,x0, gamma]
x = df.NM.to_numpy()
y_data =df.iloc[:,1].to_numpy() 

fit_params, _ = curve_fit(lorentzian, x, y_data, p0=initial_guess,maxfev=40000000)

# Generate the fitted curve
y_fit = lorentzian(x, *fit_params)

print("AR MAX ",df.NM.iloc[y_fit.argmax()])

# Plot the data and the fitted curve
plt.figure()
plt.plot(x, y_data, 'g.', label='Data')
plt.plot(x, y_fit, 'b', label='AR')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# AR MAX  459.61274519339827

# %%
from scipy.signal import lfilter

n = 15  # the larger n is, the smoother curve will be
b = [1.0 / n] * n
a = 1
yy = lfilter(b, a, y_data)
plt.plot(x, yy, linewidth=2, linestyle="-", c="b")  # smooth by filter

# %%
fit_params, _ = curve_fit(lorentzian, x, yy, p0=initial_guess,maxfev=40000000)

# Generate the fitted curve
y_fit = lorentzian(x, *fit_params)

# %%
print("AR MAX ",df.NM.iloc[y_fit.argmax()])

# Plot the data and the fitted curve
plt.figure()
plt.plot(x, yy, 'g.', label='Data')
plt.plot(x, y_fit, 'b', label='AR')

plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()
# Out:
# AR MAX  466.76195735542694

# %%
df.NM.iloc[yy.argmax()]
# Out:
# 469.6179840827391

# %%
def lorenzian_derivative(x, A, x0, gamma):
    numerator = 2 * A * gamma**2 * (x - x0)
    denominator = ((x - x0)**2 + gamma**2)**2
    return numerator / denominator

# Fonksiyonun tepe noktası olduğu düşünülen x değerleri
x_values = df.NM.iloc[y_fit.argmax()-40:y_fit.argmax()+40] # Bu listeye uygun x değerlerini ekleyin
# Türevi sıfır olan noktaları bulun
for x in x_values:
    derivative_at_x = lorenzian_derivative(x, A, x0, gamma)
    if abs(derivative_at_x) < 0.0001: # Küçük bir eşik değeri belirleyebilirsiniz
        # Fonksiyonun türevi sıfır olduğu noktayı bulduk
        # Şimdi bu noktada fonksiyonun değerini hesaplayarak global maksimumu bulalım
        maximum_value = (A * gamma**2) / (gamma**2)
        print(f"Global maksimum değer: {maximum_value} at x={x}")
# Out:
# Global maksimum değer: 0.09463919098664426 at x=455.3169848005438
# Global maksimum değer: 0.09463919098664426 at x=455.6035135740829
# Global maksimum değer: 0.09463919098664426 at x=455.8900217023603
# Global maksimum değer: 0.09463919098664426 at x=456.17650917777644
# Global maksimum değer: 0.09463919098664426 at x=456.4629759927319
# Global maksimum değer: 0.09463919098664426 at x=456.7494221396273
# Global maksimum değer: 0.09463919098664426 at x=457.03584761086313
# Global maksimum değer: 0.09463919098664426 at x=457.32225239884
# Global maksimum değer: 0.09463919098664426 at x=457.6086364959585
# Global maksimum değer: 0.09463919098664426 at x=457.89499989461905
# Global maksimum değer: 0.09463919098664426 at x=458.1813425872223
# Global maksimum değer: 0.09463919098664426 at x=458.46766456616876
# Global maksimum değer: 0.09463919098664426 at x=458.75396582385906
# Global maksimum değer: 0.09463919098664426 at x=459.0402463526937
# Global maksimum değer: 0.09463919098664426 at x=459.3265061450732
# Global maksimum değer: 0.09463919098664426 at x=459.61274519339827
# Global maksimum değer: 0.09463919098664426 at x=459.89896349006926
# Global maksimum değer: 0.09463919098664426 at x=460.1851610274869
# Global maksimum değer: 0.09463919098664426 at x=460.47133779805165
# Global maksimum değer: 0.09463919098664426 at x=460.7574937941641
# Global maksimum değer: 0.09463919098664426 at x=461.0436290082248
# Global maksimum değer: 0.09463919098664426 at x=461.32974343263425
# Global maksimum değer: 0.09463919098664426 at x=461.6158370597931
# Global maksimum değer: 0.09463919098664426 at x=461.90190988210185
# Global maksimum değer: 0.09463919098664426 at x=462.1879618919611
# Global maksimum değer: 0.09463919098664426 at x=462.47399308177137
# Global maksimum değer: 0.09463919098664426 at x=462.7600034439332
# Global maksimum değer: 0.09463919098664426 at x=463.0459929708472
# Global maksimum değer: 0.09463919098664426 at x=463.33196165491387
# Global maksimum değer: 0.09463919098664426 at x=463.6179094885338
# Global maksimum değer: 0.09463919098664426 at x=463.90383646410754
# Global maksimum değer: 0.09463919098664426 at x=464.1897425740357
# Global maksimum değer: 0.09463919098664426 at x=464.4756278107187
# Global maksimum değer: 0.09463919098664426 at x=464.7614921665572
# Global maksimum değer: 0.09463919098664426 at x=465.0473356339518
# Global maksimum değer: 0.09463919098664426 at x=465.33315820530294
# Global maksimum değer: 0.09463919098664426 at x=465.6189598730112
# Global maksimum değer: 0.09463919098664426 at x=465.9047406294772
# Global maksimum değer: 0.09463919098664426 at x=466.1905004671014
# Global maksimum değer: 0.09463919098664426 at x=466.4762393782845
# Global maksimum değer: 0.09463919098664426 at x=466.76195735542694
# Global maksimum değer: 0.09463919098664426 at x=467.04765439092927
# Global maksimum değer: 0.09463919098664426 at x=467.33333047719213
# Global maksimum değer: 0.09463919098664426 at x=467.61898560661604
# Global maksimum değer: 0.09463919098664426 at x=467.9046197716015
# Global maksimum değer: 0.09463919098664426 at x=468.1902329645491
# Global maksimum değer: 0.09463919098664426 at x=468.47582517785946
# Global maksimum değer: 0.09463919098664426 at x=468.7613964039331
# Global maksimum değer: 0.09463919098664426 at x=469.0469466351705
# Global maksimum değer: 0.09463919098664426 at x=469.3324758639724
# Global maksimum değer: 0.09463919098664426 at x=469.6179840827391
# Global maksimum değer: 0.09463919098664426 at x=469.90347128387134
# Global maksimum değer: 0.09463919098664426 at x=470.18893745976965
# Global maksimum değer: 0.09463919098664426 at x=470.4743826028345
# Global maksimum değer: 0.09463919098664426 at x=470.75980670546653
# Global maksimum değer: 0.09463919098664426 at x=471.0452097600663
# Global maksimum değer: 0.09463919098664426 at x=471.33059175903435
# Global maksimum değer: 0.09463919098664426 at x=471.61595269477124
# Global maksimum değer: 0.09463919098664426 at x=471.9012925596775
# Global maksimum değer: 0.09463919098664426 at x=472.18661134615365
# Global maksimum değer: 0.09463919098664426 at x=472.47190904660033
# Global maksimum değer: 0.09463919098664426 at x=472.7571856534181
# Global maksimum değer: 0.09463919098664426 at x=473.0424411590074
# Global maksimum değer: 0.09463919098664426 at x=473.32767555576896
# Global maksimum değer: 0.09463919098664426 at x=473.6128888361032
# Global maksimum değer: 0.09463919098664426 at x=473.8980809924107
# Global maksimum değer: 0.09463919098664426 at x=474.18325201709206
# Global maksimum değer: 0.09463919098664426 at x=474.4684019025478
# Global maksimum değer: 0.09463919098664426 at x=474.7535306411785
# Global maksimum değer: 0.09463919098664426 at x=475.03863822538466
# Global maksimum değer: 0.09463919098664426 at x=475.3237246475669
# Global maksimum değer: 0.09463919098664426 at x=475.6087899001258
# Global maksimum değer: 0.09463919098664426 at x=475.89383397546186
# Global maksimum değer: 0.09463919098664426 at x=476.1788568659756
# Global maksimum değer: 0.09463919098664426 at x=476.46385856406766
# Global maksimum değer: 0.09463919098664426 at x=476.7488390621386
# Global maksimum değer: 0.09463919098664426 at x=477.03379835258886
# Global maksimum değer: 0.09463919098664426 at x=477.3187364278191
# Global maksimum değer: 0.09463919098664426 at x=477.6036532802298
# Global maksimum değer: 0.09463919098664426 at x=477.88854890222166

# %%
import numpy as np
from scipy.optimize import curve_fit

# Karşılık gelen x değerleri
x_values =x  # Varsayılan olarak [0, 1, 2, ..., len(y_values) - 1]

# Lorenzian fonksiyonu
def lorenzian(x, A, x0, gamma):
    return A * (gamma**2) / ((x - x0)**2 + gamma**2)

# Fonksiyona başlangıç tahmin değerleri vererek en uygun parametreleri bul
initial_guess = [1.0, np.argmax(y_data), 1.0]  # [A, x0, gamma]
optimal_params, cov_matrix = curve_fit(lorenzian, x_values, y_data, p0=initial_guess, maxfev = 100000)

A_optimal, x0_optimal, gamma_optimal = optimal_params

print(f"En uygun A değeri: {A_optimal}")
print(f"En uygun x0 değeri: {x0_optimal}")
print(f"En uygun gamma değeri: {gamma_optimal}")
# Out:
# En uygun A değeri: 386.268864202092
# En uygun x0 değeri: 11548.234643427684
# En uygun gamma değeri: 136.60900761731347
